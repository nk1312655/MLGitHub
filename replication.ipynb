# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression, LassoLarsIC
from sklearn.metrics import r2_score
import os

# %% [markdown]
# ## Observations
#
#  - Food, Servs, Whlsl are a bit different. Especially Food.
#  - The others are reasonably good

# %% [markdown]
# ## Data

# %%
ind = pd.read_csv('30ValueWeightedIndustry.csv')
ind.columns = [s.strip() for s in ind.columns]
ind.set_index('Date',inplace=True)
ind_names = ind.columns.tolist()

rf = pd.read_csv('tbillrt.csv')
rf.rename(columns={'Unnamed: 0':'Date'},inplace=True)
rf.set_index('Date',inplace=True)

for col in ind.columns:
    ind[col] = ind[col] - rf['RF']

for col in ind.columns:
    ind[col+'_lead'] = ind[col].shift(-1)

ind = ind[ind.index>195911]
ind = ind[ind.index<201701]

# %% [markdown]
# ----
# Example

# %%
X = ind[ind_names].values[:-1,:]
Y = ind.drop(ind_names,axis=1).values[:-1,:]

lasso = LassoLarsIC(criterion='aic')
lasso = lasso.fit(X,Y[:,1])

x_non0_index = np.where(abs(lasso.coef_) > 1e-6)[0]

ols = LinearRegression()
ols.fit(X[:,x_non0_index], Y[:,1])

ols.coef_

l = [np.nan]*X.shape[1]
for i in range(len(ols.coef_)):
    l[x_non0_index[i]] = ols.coef_[i]

# %% [markdown]
# ----

# %% [markdown]
# ## Table 2

# %%
def lasso_ols(df, model):
    """
    1. Apply Lasso for selection of X,
    2. Drop x with zero coefficient,
    3. Apply OLS to estimate coefficients and r-squared
    """
    X = df[ind_names].values[:-1,:]
    Y = df.drop(ind_names,axis=1).values[:-1,:]
    n_x = X.shape[1]
    result = []
    
    for i in range(Y.shape[1]):
        y = Y[:,i]
        # Lasso
        lasso = LassoLarsIC(criterion='aic').fit(X,y)
        x_non0_index = np.where(abs(lasso.coef_) > 1e-6)[0]
        # OLS
        if x_non0_index.size == 0:
            result.append([np.nan]*n_x)
            continue
        ols = LinearRegression().fit(X[:,x_non0_index], y)
        y_pred = ols.predict(X[:, x_non0_index])
        rsquare = r2_score(y, y_pred)*100
        estimate = [np.nan]*n_x
        for i in range(len(ols.coef_)):
            estimate[x_non0_index[i]] = ols.coef_[i]
        estimate.append(rsquare)
        result.append(estimate)
        
    output = pd.DataFrame(result).T
    output.index = ind_names+['R-squared']
    output.columns = list(ind_names)
    return output

# %%
test = lasso_ols(ind,LassoLarsIC(criterion='aic'))

# %% [markdown]
#  - Food, Servs, Whlsl are a bit different. Especially Food.

# %%
test.iloc[:,0:10]
# Out:
#            Food      Beer     Smoke     Games     Books     Hshld     Clths  \
# Food        NaN  0.124806       NaN       NaN       NaN       NaN       NaN
# Beer        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Smoke       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Games       NaN       NaN       NaN       NaN  0.028013       NaN       NaN
# Books       NaN       NaN       NaN  0.177221  0.035296       NaN       NaN
# Hshld       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Clths       NaN  0.052488       NaN  0.053002       NaN  0.098236  0.105597
# Hlth        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Chems       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Txtls       NaN       NaN  0.065474       NaN       NaN       NaN       NaN
# Cnstr       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Steel       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# FabPr       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ElcEq       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Autos       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Carry       NaN       NaN  0.168775       NaN       NaN       NaN       NaN
# Mines       NaN       NaN -0.022502       NaN       NaN       NaN       NaN
# Coal        NaN -0.061358 -0.034769 -0.070957 -0.042138 -0.052773 -0.059536
# Oil         NaN       NaN -0.104898       NaN -0.167063       NaN -0.131776
# Util        NaN       NaN  0.273997       NaN  0.130798       NaN  0.135000
# Telcm       NaN       NaN -0.107667       NaN       NaN       NaN       NaN
# Servs       NaN       NaN -0.153268       NaN  0.050454       NaN  0.096573
# BusEq       NaN       NaN       NaN       NaN  0.062693       NaN       NaN
# Paper       NaN       NaN -0.193588       NaN       NaN       NaN       NaN
# Trans       NaN       NaN  0.096606       NaN       NaN       NaN       NaN
# Whlsl       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Rtail       NaN       NaN       NaN       NaN  0.029641  0.046517  0.056044
# Meals       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# Fin         NaN       NaN  0.110436  0.103656  0.081703       NaN       NaN
# Other       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# R-squared   NaN  2.510027  6.578419  5.047827  6.301974  2.949288  5.190776
#
#                Hlth     Chems     Txtls
# Food            NaN       NaN       NaN
# Beer            NaN       NaN       NaN
# Smoke           NaN       NaN       NaN
# Games           NaN       NaN       NaN
# Books      0.095220       NaN       NaN
# Hshld           NaN       NaN       NaN
# Clths           NaN  0.075449  0.084505
# Hlth            NaN       NaN       NaN
# Chems           NaN       NaN       NaN
# Txtls           NaN       NaN       NaN
# Cnstr           NaN       NaN       NaN
# Steel           NaN       NaN       NaN
# FabPr           NaN       NaN       NaN
# ElcEq           NaN       NaN       NaN
# Autos           NaN       NaN  0.110299
# Carry           NaN       NaN       NaN
# Mines     -0.059423       NaN       NaN
# Coal      -0.045565       NaN -0.071132
# Oil             NaN       NaN -0.154340
# Util       0.110406       NaN       NaN
# Telcm           NaN       NaN       NaN
# Servs           NaN       NaN       NaN
# BusEq           NaN       NaN       NaN
# Paper           NaN       NaN       NaN
# Trans           NaN       NaN       NaN
# Whlsl           NaN       NaN       NaN
# Rtail           NaN       NaN  0.066191
# Meals           NaN       NaN       NaN
# Fin             NaN       NaN  0.186914
# Other           NaN       NaN       NaN
# R-squared  2.686445  0.763784  7.915102

# %%
test.iloc[:,10:20]
# Out:
#               Cnstr     Steel     FabPr     ElcEq     Autos     Carry  Mines  \
# Food            NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Beer            NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Smoke           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Games           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Books           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Hshld           NaN       NaN       NaN       NaN -0.300332       NaN    NaN
# Clths      0.035858       NaN       NaN       NaN  0.036953       NaN    NaN
# Hlth            NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Chems           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Txtls           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Cnstr           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Steel           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# FabPr           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# ElcEq           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Autos           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Carry           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Mines           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Coal      -0.060901       NaN       NaN       NaN -0.045291       NaN    NaN
# Oil       -0.136165       NaN       NaN       NaN -0.127713       NaN    NaN
# Util       0.151082       NaN       NaN       NaN  0.165739       NaN    NaN
# Telcm           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Servs           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# BusEq           NaN       NaN       NaN       NaN  0.120253       NaN    NaN
# Paper           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Trans      0.064967       NaN  0.055255       NaN       NaN  0.164893    NaN
# Whlsl           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Rtail      0.000740       NaN       NaN       NaN  0.182671       NaN    NaN
# Meals           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# Fin        0.149855  0.153505  0.090879  0.102664  0.137760       NaN    NaN
# Other           NaN       NaN       NaN       NaN       NaN       NaN    NaN
# R-squared  5.132432  1.296303  1.558171  0.800391  6.128918  2.268355    NaN
#
#                Coal       Oil      Util
# Food            NaN       NaN  0.096359
# Beer      -0.270312 -0.080476 -0.101563
# Smoke     -0.093483       NaN  0.016952
# Games           NaN       NaN       NaN
# Books      0.131739       NaN       NaN
# Hshld           NaN       NaN -0.075963
# Clths           NaN       NaN       NaN
# Hlth            NaN -0.128711 -0.083205
# Chems           NaN       NaN       NaN
# Txtls           NaN       NaN       NaN
# Cnstr           NaN       NaN -0.182601
# Steel           NaN       NaN       NaN
# FabPr           NaN       NaN  0.117872
# ElcEq           NaN       NaN       NaN
# Autos     -0.001616       NaN       NaN
# Carry           NaN  0.165575  0.077145
# Mines           NaN       NaN -0.042024
# Coal       0.079590       NaN       NaN
# Oil       -0.203395       NaN -0.084342
# Util            NaN       NaN  0.092866
# Telcm           NaN       NaN  0.066894
# Servs           NaN       NaN       NaN
# BusEq           NaN       NaN  0.033907
# Paper      0.193360       NaN       NaN
# Trans           NaN       NaN       NaN
# Whlsl           NaN       NaN -0.138638
# Rtail      0.098823       NaN       NaN
# Meals           NaN       NaN       NaN
# Fin             NaN       NaN  0.126425
# Other           NaN       NaN  0.093030
# R-squared  2.854340  2.518014  7.854280

# %%
test.iloc[:,20:30]
# Out:
#               Telcm     Servs     BusEq     Paper     Trans     Whlsl  \
# Food            NaN       NaN       NaN       NaN       NaN -0.171283
# Beer      -0.061603       NaN       NaN       NaN       NaN       NaN
# Smoke     -0.030345 -0.096173 -0.144139       NaN       NaN -0.050044
# Games           NaN       NaN       NaN       NaN       NaN       NaN
# Books      0.087984  0.074627  0.121394       NaN       NaN  0.127926
# Hshld     -0.071095       NaN       NaN       NaN       NaN       NaN
# Clths           NaN       NaN       NaN  0.059780       NaN       NaN
# Hlth            NaN       NaN       NaN       NaN       NaN       NaN
# Chems           NaN       NaN       NaN       NaN       NaN       NaN
# Txtls           NaN       NaN       NaN       NaN       NaN       NaN
# Cnstr     -0.069344       NaN       NaN       NaN       NaN       NaN
# Steel           NaN -0.112693       NaN       NaN       NaN       NaN
# FabPr           NaN       NaN       NaN       NaN       NaN       NaN
# ElcEq           NaN       NaN       NaN       NaN       NaN       NaN
# Autos     -0.041899       NaN       NaN       NaN       NaN       NaN
# Carry     -0.035913       NaN       NaN       NaN       NaN  0.067293
# Mines     -0.008061       NaN       NaN       NaN       NaN       NaN
# Coal      -0.020916       NaN       NaN -0.040570       NaN -0.034687
# Oil       -0.089345 -0.116595       NaN -0.105465       NaN -0.153052
# Util       0.159040  0.130126  0.183483       NaN       NaN  0.221403
# Telcm           NaN       NaN       NaN       NaN       NaN       NaN
# Servs      0.016115  0.021681       NaN       NaN       NaN  0.039673
# BusEq      0.051054  0.058727       NaN       NaN       NaN       NaN
# Paper           NaN       NaN       NaN       NaN       NaN       NaN
# Trans           NaN       NaN       NaN       NaN       NaN       NaN
# Whlsl           NaN       NaN       NaN       NaN       NaN       NaN
# Rtail      0.099778       NaN       NaN  0.026363       NaN       NaN
# Meals     -0.102592       NaN       NaN       NaN       NaN       NaN
# Fin        0.160921  0.137758       NaN  0.104910  0.120703  0.077988
# Other           NaN       NaN       NaN       NaN       NaN  0.043288
# R-squared  5.180997  3.120243  2.732105  3.231278  1.292478  6.802911
#
#               Rtail     Meals       Fin     Other
# Food            NaN       NaN       NaN       NaN
# Beer            NaN       NaN       NaN       NaN
# Smoke           NaN -0.063862       NaN       NaN
# Games           NaN       NaN       NaN       NaN
# Books           NaN  0.058937       NaN       NaN
# Hshld           NaN       NaN       NaN       NaN
# Clths           NaN  0.096400       NaN  0.074243
# Hlth            NaN       NaN       NaN       NaN
# Chems           NaN       NaN       NaN       NaN
# Txtls           NaN       NaN       NaN       NaN
# Cnstr           NaN       NaN       NaN       NaN
# Steel           NaN -0.121746       NaN       NaN
# FabPr           NaN       NaN       NaN       NaN
# ElcEq           NaN       NaN       NaN       NaN
# Autos           NaN       NaN       NaN       NaN
# Carry           NaN  0.044485       NaN       NaN
# Mines           NaN       NaN       NaN       NaN
# Coal            NaN -0.053617       NaN       NaN
# Oil             NaN -0.149465       NaN       NaN
# Util            NaN  0.118532       NaN       NaN
# Telcm           NaN       NaN       NaN       NaN
# Servs           NaN  0.074043       NaN       NaN
# BusEq           NaN  0.062117       NaN       NaN
# Paper           NaN       NaN       NaN       NaN
# Trans           NaN       NaN       NaN       NaN
# Whlsl           NaN       NaN       NaN       NaN
# Rtail      0.126923       NaN       NaN       NaN
# Meals           NaN  0.048487       NaN       NaN
# Fin             NaN  0.052254  0.130464  0.101355
# Other           NaN       NaN       NaN       NaN
# R-squared  1.610980  7.900752  1.701229  2.686677

# %%
os.system('jupyter nbconvert --to html_toc replication.ipynb')
# Out:
# 0
